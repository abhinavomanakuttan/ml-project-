# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# In this notebook, we will explore various aspects of Data Science, including languages, libraries, and tools used in the field.
# We will also include examples of simple arithmetic operations and conversions using Python code.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - Keras

# %% [markdown]
# ## Data Science Tools
# | Tool             | Category            | Use Case                        |
# |------------------|---------------------|---------------------------------|
# | Jupyter Notebook | IDE/Notebook        | Interactive coding and analysis |
# | RStudio          | IDE/Notebook        | R programming and visualization |
# | Apache Spark     | Big Data Framework  | Distributed computing           |
# | TensorFlow       | ML/DL Library       | Deep learning                   |
# | Tableau          | Visualization Tool  | Business Intelligence (BI)      |

# %% [markdown]
# ## Arithmetic Expression Examples
# Below are examples of basic arithmetic expressions like multiplication and addition.

# %%
# Multiplication and Addition
a = 5 * 7
b = a + 10
b
# Out:
# 45

# %%
# Convert minutes to hours
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %%
# Convert minutes to hours
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives
# The objectives of this notebook are to:
# - Introduce Data Science tools, languages, and libraries
# - Demonstrate simple arithmetic operations
# - Show practical use of Python for time conversion
# - Practice creating Markdown and Code cells in Jupyter

# %% [markdown]
# ## Author
# **Author: Abhinav Omanakuttan**
